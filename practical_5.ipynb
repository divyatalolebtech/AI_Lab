# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import emoji

# %%
# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load your dataset
df = pd.read_csv("instagram_comments_curated_dataset.csv")

# %%
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

def preprocess_comment(text):
    text = re.sub(r'@\w+|#\w+|http\S+', '', str(text))
    text = emoji.demojize(text, language='en')
    tokens = text.split()
    tokens = [stemmer.stem(w.lower()) for w in tokens if w.isalpha() and w.lower() not in stop_words]
    return ' '.join(tokens)

# %%
df["ProcessedComment"] = df["Comment"].astype(str).apply(preprocess_comment)
df.to_csv("practical5_preprocessed_output.csv", index=False)
df[['Comment', 'ProcessedComment']].head()
# Out:
#                                              Comment  \
# 0                                               ❤️❤️
# 1  🥹🥹finallyyy found a solution for my biggest ha...
# 2                                   Excited to use!!
# 3  So glad that you are excited. Let us know how ...
# 4  @lovebeautyandplanet_in yes, definitely gonna ...
#
#                    ProcessedComment
# 0
# 1  found solut biggest hair problem
# 2                             excit
# 3             glad let us know work
# 4               definit gonna share
