# %% [markdown]
# # **Practical 6**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Use only non-empty processed comments
processed = df["ProcessedComment"].dropna()
processed = processed[processed != ""]

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed)
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

tfidf_df.head()
# Out:
#    allergen   biggest  bought  check  collab   definit   dm  excit     found  \
# 0       0.0  0.447214     0.0    0.0     0.0  0.000000  0.0    0.0  0.447214
# 1       0.0  0.000000     0.0    0.0     0.0  0.000000  0.0    1.0  0.000000
# 2       0.0  0.000000     0.0    0.0     0.0  0.000000  0.0    0.0  0.000000
# 3       0.0  0.000000     0.0    0.0     0.0  0.616895  0.0    0.0  0.000000
# 4       0.0  0.000000     0.0    0.0     0.0  0.000000  0.0    0.0  0.000000
#
#        glad  ...  pleas   problem  refus     share     solut  tri        us  \
# 0  0.000000  ...    0.0  0.447214    0.0  0.000000  0.447214  0.0  0.000000
# 1  0.000000  ...    0.0  0.000000    0.0  0.000000  0.000000  0.0  0.000000
# 2  0.447214  ...    0.0  0.000000    0.0  0.000000  0.000000  0.0  0.447214
# 3  0.000000  ...    0.0  0.000000    0.0  0.488754  0.000000  0.0  0.000000
# 4  0.000000  ...    0.0  0.000000    0.0  0.000000  0.000000  0.0  0.000000
#
#    use      wait      work
# 0  0.0  0.000000  0.000000
# 1  0.0  0.000000  0.000000
# 2  0.0  0.000000  0.447214
# 3  0.0  0.000000  0.000000
# 4  0.0  0.707107  0.000000
#
# [5 rows x 27 columns]
