# %% [markdown]
# # **Practical 7**

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud

# Total TF-IDF score for each term across all comments
feature_scores = tfidf_df.sum(axis=0).sort_values(ascending=False)

# ----- 1. Plot Top 10 Important Words -----
top_features = feature_scores.head(10)

plt.figure(figsize=(10, 5))
top_features.plot(kind='barh', color='skyblue')
plt.title("Top 10 Important Words (TF-IDF Scores)")
plt.xlabel("TF-IDF Score")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# ----- 2. WordCloud -----
all_text = ' '.join(df['ProcessedComment'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("WordCloud of Instagram Comments")
plt.show()
